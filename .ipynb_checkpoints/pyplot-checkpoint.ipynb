# %% [markdown]
# # Pyplot project for fundamentals of data analysis
#
# ***

# %% [markdown]
# At the start of this project, I will just be writing some general notes and ideas that I might have. Later on, I will edit down these ideas and put together the completed notebook.

# %% [markdown]
# [Gallery of Matplotlib examples](https://matplotlib.org/stable/gallery/index.html)

# %% [markdown]
# ### What I consider a 'good' graph:
# - Shows a lot of data easily and effectively
# - I find that I tend to like combined graphs that have multiple ways of showing data e.g. size, colour, position

# %% [markdown]
# ---

# %% [markdown]
# For all of these graphs, numpy and matplot lib will need to be imported

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Scatter Plot with Histograms
# This plot combines a scatter graph with histograms on the top and side of the graph (I may be able to change the position of the histograms)

# %% [markdown]
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/scatter_hist.html#sphx-glr-gallery-lines-bars-and-markers-scatter-hist-py

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# some random data
x = np.random.randn(1000)
y = np.random.randn(1000)


def scatter_hist(x, y, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)

    # the scatter plot:
    ax.scatter(x, y)

    # now determine nice limits by hand:
    binwidth = 0.25
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histx.hist(x, bins=bins)
    ax_histy.hist(y, bins=bins, orientation='horizontal')

# %%
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figure
fig = plt.figure(figsize=(8, 8))

ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)

# use the previously defined function
scatter_hist(x, y, ax, ax_histx, ax_histy)

plt.show()

# %% [markdown]
# ---
# This is the example given in the above link.
# There are some things that I would like to change about this graph. I do not like that the y axes on both histograms are different
# ---

# %%
# Seed was taken out in this run to see graph with other variations
np.random

# some random data
x = np.random.randn(1000)
y = np.random.randn(1000)


def scatter_hist(x, y, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)

    # the scatter plot:
    ax.scatter(x, y)

    # now determine nice limits by hand:
    binwidth = 0.25
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histx.hist(x, bins=bins)
    ax_histy.hist(y, bins=bins, orientation='horizontal')

# %%
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.01


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.28]

# Making the right histogram slighlty larger puts in a 25 tick on the y axis by default
# The max bin in this histogram may be less than 100
rect_histy = [left + width + spacing, bottom, 0.28, height]

# start with a square Figure
fig = plt.figure(figsize=(8, 8))

ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)

# use the previously defined function
scatter_hist(x, y, ax, ax_histx, ax_histy)

plt.show()

# %% [markdown]
# Some messing may need to be done with non-default axis as the right histogram seems to have a diferent default configuration than the top one. <br>
# My guess is that this is due to the negative numbers on the y axis of the scatter graph to be wider than the numbers on the scatter x axis are tall.

# %% [markdown]
# ***
#
# ## End
